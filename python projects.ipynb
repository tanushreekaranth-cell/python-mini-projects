# %%
#BMI CALCULATOR
height = float(input("Enter height in meters: "))
weight = float(input("Enter weight in kg: "))

bmi = weight / (height ** 2)

print("Your BMI:", round(bmi, 2))

if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal weight")
elif bmi < 30:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter height in meters:  577
# Enter weight in kg:  53
# Your BMI: 0.0
# Underweight

# %%
#TREASURE ISLAND
print("Welcome to Treasure Island 🏝️")
print("Your mission is to find the treasure.")

choice1 = input("Left or Right? ").lower()

if choice1 == "left":
    choice2 = input("Swim or Wait? ").lower()

    if choice2 == "wait":
        choice3 = input("Choose a door: Red, Blue, Yellow: ").lower()

        if choice3 == "yellow":
            print("You found the treasure 🎉")
        else:
            print("Game Over ")
    else:
        print("Game Over ")
else:
    print("Game Over BETTER LUCK NEXT TIME")
# Out:
# Welcome to Treasure Island 🏝️
# Your mission is to find the treasure.
# Left or Right?  left
# Swim or Wait?  swim
# Game Over

# %%
import random
choice=["rock","paper","scissors"]
user=input("choose rock,paper,scissors:").lower()
computer=random.choice(choice)
print("Computer's choice:",computer)
if user==computer:
    print("Draw")
elif(user=="rock" and computer=="scissors")or\
    (user=="paper" and computer=="rock")or\
    (user=="scissors" and computer=="paper"):
    print("you win!!!!!")
else:
    print("you loose")
# Out:
# choose rock,paper,scissors: rock
# Computer's choice: paper
# you loose

# %%
#HANGMAN GAME
import random
words=["python","script","java","london","coding","developer","debug",
       "pillow","parade","fan","database","soft","software","softmade"]
word=random.choice(words)
display=["_"]*len(word)
lives=6
while "_"in display and lives>0:
    print(" ".join(display))
    guess=input("guess a letter:").lower()
    if guess in word:
        for i in range(len(word)):
            if word[i]==guess:
                display[i]=guess
    else:
        lives-=1
        print("wrong guess!lives left:",lives)
if "_" not in display:
    print("you win word:",word)
else:
    print("you lose word was:",word)
# Out:
# _ _ _ _ _ _
# guess a letter: p
# wrong guess!lives left: 5
# _ _ _ _ _ _
# guess a letter: s
# wrong guess!lives left: 4
# _ _ _ _ _ _
# guess a letter: c
# wrong guess!lives left: 3
# _ _ _ _ _ _
# guess a letter: d
# _ _ _ d _ _
# guess a letter: f
# wrong guess!lives left: 2
# _ _ _ d _ _
# guess a letter: p
# wrong guess!lives left: 1
# _ _ _ d _ _
# guess a letter: a
# wrong guess!lives left: 0
# you lose word was: london

# %%
#pizza order
print("WELCOME TO THE PIZZA ORDERING USING PYTHON:")
size=input("choose size(s/m/l)").upper()
bill=0
if size=="S":
    bill=100
elif size=="M":
    bill=200
elif size=="L":
    bill=300
pepperoni=input("Add pepperoni?Y/N:").upper()
if pepperoni=="Y":
    bill+=50
cheese=input("Extra cheese ?Y/N:").upper()
if cheese=="Y":
    bill+=30
print("your total bill is",bill)
print("Thank you for ordering ,")
# Out:
# WELCOME TO THE PIZZA ORDERING USING PYTHON:
# choose size(s/m/l) m
# Add pepperoni?Y/N: n
# Extra cheese ?Y/N: y
# your total bill is 230
# Thank you for ordering ,
